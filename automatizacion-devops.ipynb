# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

import os
os.chdir('/content/drive/MyDrive/NOTEBOOKS/python-alura-curso01-basic')
os.chdir('/content/drive/MyDrive/NOTEBOOKS/python-alura-curs01-basic')
os.getcwd()
# Out:
# Mounted at /content/drive
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-1a78d40ca07b> in <cell line: 0>()
#       3
#       4 import os
# ----> 5 os.chdir('/content/drive/MyDrive/NOTEBOOKS/python-alura-curso01-basic')
#       6 os.getcwd()
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/NOTEBOOKS/python-alura-curso01-basic'
